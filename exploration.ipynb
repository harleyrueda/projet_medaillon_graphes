# %% [markdown]
# # exploration fonctions pour script generate_sample_data

# %%
import argparse
import os
import csv
import random
from tqdm import tqdm

# %%
def generate_nodes(path, count):
    labels = ['Person', 'Org', 'Paper']
    with open(os.path.join(path, 'nodes.csv'), mode='w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['id', 'label', 'name'])
        for i in tqdm(range(count), desc="Generating nodes"):
            label = random.choice(labels)
            name = f"{label.lower()}_{i}"

            if i < 5:
                print(f"Node {i}: {i}, {label}, {name}")
                
            writer.writerow([i, label, name])

# %%
os.makedirs("data/raw", exist_ok=True)

generate_nodes("data/raw", 100)
# Out:
# Generating nodes: 100%|██████████| 100/100 [00:00<00:00, 29458.52it/s]
# Node 0: 0, Org, org_0
# Node 1: 1, Person, person_1
# Node 2: 2, Person, person_2
# Node 3: 3, Person, person_3
# Node 4: 4, Org, org_4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # fonction pour generation d'edges

# %%
def generate_edges(path, count, max_node_id):
    with open(os.path.join(path, 'edges.csv'), mode='w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['src', 'dst', 'type'])
        for i in tqdm(range(count), desc="Generating edges"):
            src = random.randint(0, max_node_id - 1)
            dst = random.randint(0, max_node_id - 1)
            writer.writerow([src, dst, 'REL'])

# %%
output_path = "data/raw"
os.makedirs(output_path, exist_ok=True)

generate_edges(output_path, 200, 100)
# Out:
# Generating edges: 100%|██████████| 200/200 [00:00<00:00, 3674.48it/s]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import argparse

parser = argparse.ArgumentParser()
parser.add_argument('--nodes', type=int, default=100)
parser.add_argument('--edges', type=int, default=500)
parser.add_argument('--out', required=True)

args = parser.parse_args(args=['--out', 'data/test', '--nodes', '100', '--edges', '500'])

print(args.out)
print(args.nodes)
print(args.edges)
# Out:
# data/test
# 100
# 500
